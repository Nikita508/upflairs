# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\Python\prags\cust_satisfaction.csv')
df.head()
# raw data
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
# yes or no ,0 nd 1,---->Binary Classification
#y=Satisfaction
#x=all other remaining are taken in x
# data can be in excel,json file,xml,cloud

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
df['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71655
# Personal Travel    32249
# Name: count, dtype: int64

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %% [markdown]
# female in candidate

# %%
Female_df=df[df['Gender']=='Female']
Female_df.head()
# Out:
#    Gender   Customer Type   Type of Travel     Class             satisfaction  \
# 2  Female  Loyal Customer  Business travel  Business                satisfied
# 3  Female  Loyal Customer  Business travel  Business  neutral or dissatisfied
# 5  Female  Loyal Customer  Personal Travel       Eco  neutral or dissatisfied
# 7  Female  Loyal Customer  Business travel  Business                satisfied
# 8  Female  Loyal Customer  Business travel  Business  neutral or dissatisfied
#
#    Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 2   26             1142                       5                 4
# 3   25              562                       2                 3
# 5   26             1180                       1                 4
# 7   52             2035                       5                 5
# 8   41              853                       1                 1
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# ...

# %%
Female_df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       42458
# disloyal Customer    10269
# Name: count, dtype: int64

# %%
Female_with4_5_rating=Female_df[Female_df['Inflight entertainment']>=4]
Female_with4_5_rating
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# 2       Female  Loyal Customer  Business travel  Business
# 7       Female  Loyal Customer  Business travel  Business
# 16      Female  Loyal Customer  Business travel  Business
# 18      Female  Loyal Customer  Business travel  Business
# 21      Female  Loyal Customer  Personal Travel       Eco
# ...        ...             ...              ...       ...
# 103874  Female  Loyal Customer  Business travel  Business
# 103879  Female  Loyal Customer  Business travel  Business
# 103881  Female  Loyal Customer  Business travel  Business
# 103884  Female  Loyal Customer  Personal Travel       Eco
# 103897  Female  Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# 7                     satisfied   52             2035                       5
# ...

# %%
Female_with4_5_rating['satisfaction'].value_counts()
# Out:
# satisfaction
# satisfied                  17070
# neutral or dissatisfied    10449
# Name: count, dtype: int64

# %%
Female_with4_5_rating['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       23340
# disloyal Customer     4179
# Name: count, dtype: int64

# %%
Disloyal_female=Female_with4_5_rating[Female_with4_5_rating['Customer Type']=='disloyal Customer']
Disloyal_female
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 31      Female  disloyal Customer  Business travel       Eco
# 36      Female  disloyal Customer  Business travel  Business
# 58      Female  disloyal Customer  Business travel  Business
# 78      Female  disloyal Customer  Business travel       Eco
# 82      Female  disloyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103768  Female  disloyal Customer  Business travel  Business
# 103773  Female  disloyal Customer  Business travel       Eco
# 103785  Female  disloyal Customer  Business travel       Eco
# 103812  Female  disloyal Customer  Business travel  Business
# 103828  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 31      neutral or dissatisfied   15             1043                       5
# ...

# %%
Disloyal_female['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    3209
# satisfied                   970
# Name: count, dtype: int64

# %%
Male=df[df['Gender']=='Male']
Male
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 0        Male     Loyal Customer  Personal Travel  Eco Plus
# 1        Male  disloyal Customer  Business travel  Business
# 4        Male     Loyal Customer  Business travel  Business
# 6        Male     Loyal Customer  Personal Travel       Eco
# 9        Male  disloyal Customer  Business travel       Eco
# ...       ...                ...              ...       ...
# 103896   Male     Loyal Customer  Business travel       Eco
# 103898   Male     Loyal Customer  Personal Travel       Eco
# 103900   Male     Loyal Customer  Business travel  Business
# 103901   Male  disloyal Customer  Business travel  Business
# 103903   Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
Male['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    28686
# satisfied                  22491
# Name: count, dtype: int64

# %%
Male_with_4_5_rating=Male[Male['Inflight entertainment']>=4]
Male_with_4_5_rating
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 0        Male     Loyal Customer  Personal Travel  Eco Plus
# 13       Male     Loyal Customer  Personal Travel       Eco
# 15       Male  disloyal Customer  Business travel       Eco
# 17       Male     Loyal Customer  Business travel  Business
# 19       Male     Loyal Customer  Personal Travel       Eco
# ...       ...                ...              ...       ...
# 103891   Male     Loyal Customer  Business travel  Business
# 103894   Male     Loyal Customer  Business travel  Business
# 103896   Male     Loyal Customer  Business travel       Eco
# 103900   Male     Loyal Customer  Business travel  Business
# 103901   Male  disloyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 13                    satisfied   33              946                       4
# ...

# %%
Male_with_4_5_rating['satisfaction'].value_counts()
# Out:
# satisfaction
# satisfied                  17279
# neutral or dissatisfied     9838
# Name: count, dtype: int64

# %%
Male_with_4_5_rating['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       23527
# disloyal Customer     3590
# Name: count, dtype: int64

# %%
disloyal_male=Male_with_4_5_rating[Male_with_4_5_rating['Customer Type']=='disloyal Customer']
disloyal_male
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 15       Male  disloyal Customer  Business travel       Eco
# 59       Male  disloyal Customer  Business travel       Eco
# 62       Male  disloyal Customer  Business travel       Eco
# 72       Male  disloyal Customer  Business travel  Business
# 104      Male  disloyal Customer  Business travel  Business
# ...       ...                ...              ...       ...
# 103846   Male  disloyal Customer  Business travel  Business
# 103851   Male  disloyal Customer  Business travel       Eco
# 103857   Male  disloyal Customer  Business travel       Eco
# 103886   Male  disloyal Customer  Business travel  Business
# 103901   Male  disloyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 15      neutral or dissatisfied   13              486                       4
# 59      neutral or dissatisfied   23              446                       4
# ...

# %%
import seaborn as sns

# %%
sns.countplot(df['satisfaction'])
plt.show()

# %%
sns.countplot(df['Class'])
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
Male['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    28686
# satisfied                  22491
# Name: count, dtype: int64

# %%
satisfaction=list(Male['satisfaction'].value_counts().keys())
no_ofcounts=list(Male['satisfaction'].value_counts().values)

# %%
satisfaction
# Out:
# ['neutral or dissatisfied', 'satisfied']

# %%
plt.pie(no_ofcounts,labels=satisfaction)
plt.show()

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.duplicated().sum()  # these are not duplicates they have same value coincidently
# Out:
# np.int64(172)

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
sns.kdeplot(df['Arrival Delay in Minutes'])
plt.show()

# %%
#filling numerical-->mean
#catgorical-->mode

# %%
df[df['Arrival Delay in Minutes'].isnull()]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 213     Female     Loyal Customer  Business travel       Eco
# 1124      Male     Loyal Customer  Personal Travel       Eco
# 1529      Male     Loyal Customer  Business travel  Business
# 2004    Female  disloyal Customer  Business travel  Business
# 2108    Female     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 102067    Male     Loyal Customer  Personal Travel  Eco Plus
# 102384    Male     Loyal Customer  Business travel       Eco
# 102552  Female  disloyal Customer  Business travel       Eco
# 102960    Male     Loyal Customer  Business travel       Eco
# 103540  Female     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 213                   satisfied   38              109                       5
# ...

# %%
satisfied=df[df['satisfaction']=='satisfied']
satisfied
# Out:
#         Gender   Customer Type   Type of Travel     Class satisfaction  Age  \
# 2       Female  Loyal Customer  Business travel  Business    satisfied   26
# 4         Male  Loyal Customer  Business travel  Business    satisfied   61
# 7       Female  Loyal Customer  Business travel  Business    satisfied   52
# 13        Male  Loyal Customer  Personal Travel       Eco    satisfied   33
# 16      Female  Loyal Customer  Business travel  Business    satisfied   26
# ...        ...             ...              ...       ...          ...  ...
# 103890  Female  Loyal Customer  Business travel  Eco Plus    satisfied   56
# 103891    Male  Loyal Customer  Business travel  Business    satisfied   54
# 103894    Male  Loyal Customer  Business travel  Business    satisfied   26
# 103897  Female  Loyal Customer  Business travel  Business    satisfied   60
# 103900    Male  Loyal Customer  Business travel  Business    satisfied   49
#
# ...

# %%
sns.kdeplot(satisfied['Arrival Delay in Minutes'])
plt.show()

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
#dt={}
#map()

# %%
#for converting catgorrical to numerical
#astype used for converting true false to zero one

# %%
df2=pd.get_dummies(df).astype(int)
df2
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
df2=pd.get_dummies(df,drop_first='if_binary').astype(int)
df2
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
import pandas as pd

# %%
df['Arrival Delay in Minutes'].dtypes
# Out:
# dtype('float64')

# %%
df['Arrival Delay in Minutes'].astype(int)
# Out:
# 0         18
# 1          6
# 2          0
# 3          9
# 4          0
#           ..
# 103899     0
# 103900     0
# 103901    14
# 103902     0
# 103903     0
# Name: Arrival Delay in Minutes, Length: 103594, dtype: int64

# %%
# astype changes datatype of column

# %%
#if only two columns remove one using dropfirst
#first column will drop

# %%
# splitting x and y
x=df2.drop("satisfaction_satisfied",axis=1)
y=df2[["satisfaction_satisfied"]]

# %%
#importing sklearn
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#plot_tree(dtc)

# %%
print(dtc.score(x_train,y_train))
print(dtc.score(x_test,y_test))
# Out:
# 0.9996500754147813
# 0.8164486703026208

# %%
#prunning process-cutting branches of decision tree 
#pre and post prunning

# %%
#prediction,confusion matrix,classification report andsave model

# %%
x_train.isnull().sum()
# Out:
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# dtype: int64

# %%
x_train
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 4460     44              126                       5                 5
# 57785    51              251                       2                 2
# 38717    56              337                       1                 4
# 60454    63             1562                       1                 1
# 100669   44              283                       2                 2
# ...     ...              ...                     ...               ...
# 13111    54             1506                       4                 2
# 34913    18             1892                       2                 1
# 86876    24             1024                       5                 3
# 84990    43              693                       5                 1
# 24740    22              967                       3                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
print(lg.score(x_train,y_train)*100)
print(lg.score(x_train,y_train)*100)
# Out:
# 79.38582202111614
# 79.38582202111614

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
pred=lg.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
y_test["prediction"]=pred

# %%
y_test.head(40)
# Out:
#         satisfaction_satisfied  prediction
# 47037                        0           0
# 22791                        0           0
# 20364                        1           1
# 16200                        1           0
# 64936                        0           0
# 67341                        0           0
# 35594                        1           1
# 73097                        1           1
# 51070                        1           1
# 1193                         1           1
# 92                           0           1
# 69982                        0           0
# 6050                         1           1
# 22752                        0           1
# 56612                        1           1
# 29981                        0           0
# 47883                        1           1
# 59804                        1           1
# 32437                        1           1
# 10226                        0           1
# 82132                        1           0
# ...

# %%
matrix=confusion_matrix(y_test["satisfaction_satisfied"],y_test["prediction"])
matrix
# Out:
# array([[9526, 2225],
#        [2060, 6908]])

# %%
y_test.head(40)
# Out:
#         satisfaction_satisfied  prediction
# 47037                        0           0
# 22791                        0           0
# 20364                        1           1
# 16200                        1           0
# 64936                        0           0
# 67341                        0           0
# 35594                        1           1
# 73097                        1           1
# 51070                        1           1
# 1193                         1           1
# 92                           0           1
# 69982                        0           0
# 6050                         1           1
# 22752                        0           1
# 56612                        1           1
# 29981                        0           0
# 47883                        1           1
# 59804                        1           1
# 32437                        1           1
# 10226                        0           1
# 82132                        1           0
# ...

# %%
x_test.shape
# Out:
# (20719, 12)

# %%
print(classification_report(y_test["satisfaction_satisfied"],y_test["prediction"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82     11751
#            1       0.76      0.77      0.76      8968
#
#     accuracy                           0.79     20719
#    macro avg       0.79      0.79      0.79     20719
# weighted avg       0.79      0.79      0.79     20719

# %%
(9684+6862)/(9684+2143+2030+6862)
# Out:
# 0.7985906655726628

# %%
(9684)/(9684+2143)
# Out:
# 0.8188044305402892

# %%
df["satisfaction"].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58697
# satisfied                  44897
# Name: count, dtype: int64

# %%
x_train
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 4460     44              126                       5                 5
# 57785    51              251                       2                 2
# 38717    56              337                       1                 4
# 60454    63             1562                       1                 1
# 100669   44              283                       2                 2
# ...     ...              ...                     ...               ...
# 13111    54             1506                       4                 2
# 34913    18             1892                       2                 1
# 86876    24             1024                       5                 3
# 84990    43              693                       5                 1
# 24740    22              967                       3                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
import joblib

# %%
joblib.dump(lg,"LogisticRegression.lb")
# Out:
# ['LogisticRegression.lb']

# %%
x_train
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 4460     44              126                       5                 5
# 57785    51              251                       2                 2
# 38717    56              337                       1                 4
# 60454    63             1562                       1                 1
# 100669   44              283                       2                 2
# ...     ...              ...                     ...               ...
# 13111    54             1506                       4                 2
# 34913    18             1892                       2                 1
# 86876    24             1024                       5                 3
# 84990    43              693                       5                 1
# 24740    22              967                       3                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# ...

# %%
#decision tree=regression+classification
