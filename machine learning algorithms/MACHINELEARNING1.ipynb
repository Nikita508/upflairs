# %% [markdown]
# Linear regression algorithm

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Gathering data

# %%
df=pd.read_csv(r'D:\Python\Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# we have given all parameters to the X
# and price is given to the Y
# if Y variable is continuos then it is REGRESSION

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df['brand'].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
brand_ls=['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
       'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
       'Benelli', 'Triumph', 'Ducati', 'BMW']

# %%
df=df[df['brand'].isin(brand_ls)]
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %% [markdown]
# ML algorithms can not accept any alphabetical data it only take numerical data so we can try to represent the categorical data as numerical data

# %%
catgorical=df.select_dtypes(include='O') 
catgorical.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
numerical=df.select_dtypes(exclude='O')
numerical
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7307 rows x 4 columns]

# %%
catgorical['owner'].value_counts()
# Out:
# owner
# First Owner             6628
# Second Owner             586
# Third Owner               83
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt1={'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner or More':4}
catgorical['owner']=catgorical['owner'].map(dt1)

# %%
catgorical
# Out:
#                                  bike_name       city  owner            brand
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad    1.0              TVS
# 1              Royal Enfield Classic 350cc      Delhi    1.0    Royal Enfield
# 2                     Triumph Daytona 675R      Delhi    1.0          Triumph
# 3                     TVS Apache RTR 180cc  Bangalore    1.0              TVS
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    1.0           Yamaha
# ...                                    ...        ...    ...              ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi    1.0             Hero
# 9369                   Bajaj Avenger 220cc  Bangalore    1.0            Bajaj
# 9370        Harley-Davidson Street 750 ABS    Jodhpur    1.0  Harley-Davidson
# 9371                 Bajaj Dominar 400 ABS  Hyderabad    1.0            Bajaj
# 9372              Bajaj Avenger Street 220  Hyderabad    1.0            Bajaj
#
# [7307 rows x 4 columns]

# %%
brand_ls
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %% [markdown]
# Creating dictionary using this brand list

# %%
# dt={}
# for i in range(0,len(brand_ls)):
#     dt[brand_ls[i]]=i

# %%
dt={item:i for i,item in enumerate(brand_ls,start=1)}

# %%
dt
# Out:
# {'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
catgorical['brand']=catgorical['brand'].map(dt)

# %%
catgorical['brand']
# Out:
# 0        6
# 1        2
# 2       14
# 3        6
# 4        5
#         ..
# 9362     3
# 9369     1
# 9370     9
# 9371     1
# 9372     1
# Name: brand, Length: 7307, dtype: int64

# %%
catgorical
# Out:
#                                  bike_name       city  owner  brand
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad    1.0      6
# 1              Royal Enfield Classic 350cc      Delhi    1.0      2
# 2                     Triumph Daytona 675R      Delhi    1.0     14
# 3                     TVS Apache RTR 180cc  Bangalore    1.0      6
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    1.0      5
# ...                                    ...        ...    ...    ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi    1.0      3
# 9369                   Bajaj Avenger 220cc  Bangalore    1.0      1
# 9370        Harley-Davidson Street 750 ABS    Jodhpur    1.0      9
# 9371                 Bajaj Dominar 400 ABS  Hyderabad    1.0      1
# 9372              Bajaj Avenger Street 220  Hyderabad    1.0      1
#
# [7307 rows x 4 columns]

# %% [markdown]
# Removing column bike name,city as they are not impacting the price of the bike

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
catgorical['owner_name']="Ranjit sir "

# %%
catgorical
# Out:
#                                  bike_name       city  owner  brand  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad    1.0      6
# 1              Royal Enfield Classic 350cc      Delhi    1.0      2
# 2                     Triumph Daytona 675R      Delhi    1.0     14
# 3                     TVS Apache RTR 180cc  Bangalore    1.0      6
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore    1.0      5
# ...                                    ...        ...    ...    ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi    1.0      3
# 9369                   Bajaj Avenger 220cc  Bangalore    1.0      1
# 9370        Harley-Davidson Street 750 ABS    Jodhpur    1.0      9
# 9371                 Bajaj Dominar 400 ABS  Hyderabad    1.0      1
# 9372              Bajaj Avenger Street 220  Hyderabad    1.0      1
#
#        owner_name
# 0     Ranjit sir
# 1     Ranjit sir
# 2     Ranjit sir
# 3     Ranjit sir
# 4     Ranjit sir
# ...           ...
# 9362  Ranjit sir
# ...

# %%
catgorical.drop(['bike_name','city','owner_name'],axis=1,inplace=True)

# %%
catgorical
# Out:
#       owner  brand
# 0       1.0      6
# 1       1.0      2
# 2       1.0     14
# 3       1.0      6
# 4       1.0      5
# ...     ...    ...
# 9362    1.0      3
# 9369    1.0      1
# 9370    1.0      9
# 9371    1.0      1
# 9372    1.0      1
#
# [7307 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df2=pd.concat([catgorical,numerical],axis=1)
df2
# Out:
#       owner  brand     price  kms_driven  age  power
# 0       1.0      6   35000.0     17654.0  3.0  110.0
# 1       1.0      2  119900.0     11000.0  4.0  350.0
# 2       1.0     14  600000.0       110.0  8.0  675.0
# 3       1.0      6   65000.0     16329.0  4.0  180.0
# 4       1.0      5   80000.0     10000.0  3.0  150.0
# ...     ...    ...       ...         ...  ...    ...
# 9362    1.0      3   25000.0     48587.0  8.0  150.0
# 9369    1.0      1   35000.0     60000.0  9.0  220.0
# 9370    1.0      9  450000.0      3430.0  4.0  750.0
# 9371    1.0      1  139000.0     21300.0  4.0  400.0
# 9372    1.0      1   80000.0      7127.0  5.0  220.0
#
# [7307 rows x 6 columns]

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# owner         0
# brand         0
# price         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %% [markdown]
# feature,variable=column
# dataset must be in x and y

# %%
# dataset->features->target->x_train,y_train->ML Model
# do not access rows using indexing
# select randomly not in sequence=Train test split

# %%
x=df2.drop("price",axis=1)
y=df2[["price"]]

# %%
df2.isnull().sum()
# Out:
# owner         0
# brand         0
# price         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
x
# Out:
#       owner  brand  kms_driven  age  power
# 0       1.0      6     17654.0  3.0  110.0
# 1       1.0      2     11000.0  4.0  350.0
# 2       1.0     14       110.0  8.0  675.0
# 3       1.0      6     16329.0  4.0  180.0
# 4       1.0      5     10000.0  3.0  150.0
# ...     ...    ...         ...  ...    ...
# 9362    1.0      3     48587.0  8.0  150.0
# 9369    1.0      1     60000.0  9.0  220.0
# 9370    1.0      9      3430.0  4.0  750.0
# 9371    1.0      1     21300.0  4.0  400.0
# 9372    1.0      1      7127.0  5.0  220.0
#
# [7297 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7297 rows x 1 columns]

# %%
df2.isnull().sum()
# Out:
# owner         0
# brand         0
# price         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# X AND Y TRAINING SPLIT

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)  #test size 20% other remaing is 80 #train size

# %% [markdown]
# by head->
# x_test pass in ml model instead of x_train
# while testing only x part is given, xtest is given and as output it give y.

# %% [markdown]
# Training Algoritm --Linear Regression

# %% [markdown]
# Linear regression is class so we need to make object

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Making object

# %%
lg=LinearRegression()

# %% [markdown]
# Algorithm training
# func for taining =fit()passing training data for training purpose

# %%
x_train.isnull().sum()
# Out:
# owner         0
# brand         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Round of function for rounding off

# %% [markdown]
# initially we have 2 variable xtrain,ytrain and when we pass it to algorithm we get xtest ,ytest

# %%
print("Training Score:",round(lg.score(x_train,y_train)*100 ,2)) #training and testing
# Out:
# Training Score: 73.45

# %%
print("Testing Score:",round(lg.score(x_test,y_test)*100 ,2))
# Out:
# Testing Score: 76.61

# %% [markdown]
# accuracy acheiving  and model evaluation step and it should be more than 90%
# diff btw training and testing score it should not be more than five ,if it is then its underfit or overfit
# model evaluation == whether model is over fit or under fit or perfect(generalised)
# model overfit if training score is high and testing score low
# training score==high and testing score=low==Overfit problem
# training score==low and testing score=high/low not assured==underfit problem

# %% [markdown]
# Generalised Model
# diff should not more then 5
# model shouldnot be overfit and underfit
# Accuracy should be high on both train and test data

# %% [markdown]
# Prediction
# xdata is passed and give prediction and we will calll it by head
# prediction value get compared to value of ytest
# prediction variable is by head

# %%
y_hat=lg.predict(x_test)

# %%
x_test
# Out:
#       owner  brand  kms_driven   age  power
# 8518    1.0      1     34879.0  10.0  125.0
# 4796    1.0      5      8500.0   9.0  150.0
# 2623    1.0      2     20000.0   4.0  350.0
# 4703    1.0      7     13600.0   6.0  390.0
# 2305    1.0      3     19000.0   4.0  110.0
# ...     ...    ...         ...   ...    ...
# 3080    1.0      1     44002.0   5.0  100.0
# 7273    1.0      1     35466.0   5.0  150.0
# 4760    1.0      2    300965.0   7.0  350.0
# 7809    1.0      1      6600.0   5.0  220.0
# 8400    1.0      3     34968.0  14.0  150.0
#
# [1460 rows x 5 columns]

# %%
x_test.shape
# Out:
# (1460, 5)

# %%
y_test["prediction"]=y_hat

# %%
y_test["prediction"]=y_test["prediction"].map(lambda x:round(x,2))

# %%
y_test
# Out:
#          price  prediction
# 8518   17998.0    -9915.50
# 4796   32000.0    57741.02
# 2623  105200.0   140198.05
# 4703  111400.0   218750.26
# 2305   32000.0    23922.89
# ...        ...         ...
# 3080   23000.0   -10827.51
# 7273   32000.0    16671.05
# 4760   91804.0   109889.10
# 7809   55005.0    56516.10
# 8400   11900.0    17658.52
#
# [1460 rows x 2 columns]

# %%
y_test.head(40)
# Out:
#          price  prediction
# 8518   17998.0    -9915.50
# 4796   32000.0    57741.02
# 2623  105200.0   140198.05
# 4703  111400.0   218750.26
# 2305   32000.0    23922.89
# 3014   28000.0    13353.83
# 5328   25000.0    -4908.32
# 2975   24000.0    22878.69
# 12     78000.0    48170.57
# 4208   64000.0     8607.48
# 3073   21000.0     5255.60
# 7363   16500.0    -1190.23
# 8095   42000.0    10255.22
# 5015   24000.0     9791.87
# 6315  114000.0   215872.07
# 4658   43999.0    34378.20
# 2139   20400.0   -17328.26
# 9009   60000.0    18380.49
# 626    63000.0    58146.89
# 8929   30000.0    18421.20
# 7664   36000.0    14640.19
# 5287  137999.0   218973.24
# 143    72000.0    57337.24
# 8575   62000.0    18218.84
# 5473   42000.0    13428.99
# 5109   91000.0    69481.73
# 4785  170000.0   205737.91
# 4113   62000.0    71003.94
# 8224   55000.0    50402.16
# 6665   39000.0    16232.89
# 3966   39000.0     2852.10
# 6129   34800.0    15595.81
# 8288   45000.0    41185.71
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rdf=RandomForestRegressor()

# %%
rdf.fit(x_train,y_train)
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %% [markdown]
# to improve accuracy we have seen new algo

# %%
print("Training Score:",round(rdf.score(x_train,y_train)*100 ,2)) #training and testing 
print("Testing Score:",round(rdf.score(x_test,y_test["price"])*100 ,2))
# Out:
# Training Score: 98.44
# Testing Score: 91.21

# %% [markdown]
# to save this variable
# importing new library joblib

# %%
lg
# Out:
# LinearRegression()

# %%
ls =['ARUSHI',"nikita","prag","tammna","salu"]
ls
# Out:
# ['ARUSHI', 'nikita', 'prag', 'tammna', 'salu']

# %%
import joblib

# %% [markdown]
# dump give in encrypted form so for reading it we used load function

# %%
joblib.dump(ls,"favorite.lb")
# Out:
# ['favorite.lb']

# %%
favorite=joblib.load("favorite.lb")
favorite
# Out:
# ['ARUSHI', 'nikita', 'prag', 'tammna', 'salu']

# %%
joblib.dump(lg,"LinearRegressionmodel.lb")
# Out:
# ['LinearRegressionmodel.lb']

# %% [markdown]
# we will not add .lb as others get to know type of file

# %%
model=joblib.load("LinearRegressionmodel.lb")
model
# Out:
# LinearRegression()
