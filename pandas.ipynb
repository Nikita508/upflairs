# %%
PANDAS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 PANDAS
#
# NameError: name 'PANDAS' is not defined

# %%
import pandas as pd

# %%
dt={"name":['anku','aman'],"class":[1,2],"sub":['math','eng']}
dt
# Out:
# {'name': ['anku', 'aman'], 'class': [1, 2], 'sub': ['math', 'eng']}

# %%
df=pd.DataFrame(dt)
df
# Out:
#    name  class   sub
# 0  anku      1  math
# 1  aman      2   eng

# %%
dt={"name":['nikita','pragati','arushi','kartik'],
    "branch":['cse','ece','it','cse'],
    "class":[1,2,3,4],
    "city":['ajmer','agra','jaipur','kota']}
dt
# Out:
# {'name': ['nikita', 'pragati', 'arushi', 'kartik'],
#  'branch': ['cse', 'ece', 'it', 'cse'],
#  'class': [1, 2, 3, 4],
#  'city': ['ajmer', 'agra', 'jaipur', 'kota']}

# %%
df=pd.DataFrame(dt)
df
# Out:
#       name branch  class    city
# 0   nikita    cse      1   ajmer
# 1  pragati    ece      2    agra
# 2   arushi     it      3  jaipur
# 3   kartik    cse      4    kota

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['name']
# Out:
# 0    anku
# 1    aman
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['name']
# Out:
# 0     nikita
# 1    pragati
# 2     arushi
# 3     kartik
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

# %%
##  csv file
df=pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()  # give high level information about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
### accessing
df.price  # exracting one column
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
# other way for 1 column
df['price']
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
# column 1 but in form of dataframe
df[['price']]
# Out:
#           price
# 0       35000.0
# 1      119900.0
# 2      600000.0
# 3       65000.0
# 4       80000.0
# ...         ...
# 32643   39000.0
# 32644   30000.0
# 32645   60000.0
# 32646   15600.0
# 32647   22000.0
#
# [32648 rows x 1 columns]

# %%
#multiple columns  2 columns
df[['price','city','brand']]
# Out:
#           price       city          brand
# 0       35000.0  Ahmedabad            TVS
# 1      119900.0      Delhi  Royal Enfield
# 2      600000.0      Delhi        Triumph
# 3       65000.0  Bangalore            TVS
# 4       80000.0  Bangalore         Yamaha
# ...         ...        ...            ...
# 32643   39000.0      Delhi           Hero
# 32644   30000.0     Karnal            TVS
# 32645   60000.0      Delhi          Bajaj
# 32646   15600.0     Jaipur           Hero
# 32647   22000.0       Pune          Bajaj
#
# [32648 rows x 3 columns]

# %%
# fetching records from specific row and column
#loc &iloc
#los =indexes for rows and labels for column

df.loc[10:20,['bike_name','price','city','kms_driven']]
# Out:
#                    bike_name     price       city  kms_driven
# 10  Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore     20000.0
# 11         Yamaha FZ25 250cc   95000.0  Bangalore      9665.0
# 12        Bajaj Pulsar NS200   78000.0  Bangalore      9900.0
# 13       Bajaj Discover 100M   29499.0      Delhi     20000.0
# 14       Bajaj Discover 125M   29900.0      Delhi     20000.0
# 15    Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0
# 16    Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0
# 17    Suzuki Gixxer SF 150cc   48000.0     Mumbai     24725.0
# 18        Benelli 302R 300CC  240000.0     Mumbai     15025.0
# 19       Bajaj Discover 125M   29900.0      Delhi     20000.0
# 20    Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0

# %%
df.loc[20:35,['owner','age','power','brand']]
# Out:
#            owner   age  power          brand
# 20   First Owner   3.0  200.0          Bajaj
# 21   First Owner   5.0  150.0         Suzuki
# 22   First Owner   2.0  110.0           Hero
# 23   First Owner   5.0  500.0  Royal Enfield
# 24   First Owner   6.0  150.0         Yamaha
# 25   First Owner   4.0  200.0          Bajaj
# 26   First Owner  16.0  125.0           Hero
# 27  Second Owner   7.0  125.0          Honda
# 28   First Owner   8.0  150.0          Bajaj
# 29   First Owner   2.0  160.0          Honda
# 30   First Owner   3.0  200.0          Bajaj
# 31  Second Owner   4.0  150.0         Yamaha
# 32   First Owner   6.0  220.0          Bajaj
# 33   First Owner   4.0  390.0            KTM
# 34   First Owner   8.0  150.0          Honda
# 35  Second Owner   8.0  200.0            KTM

# %%
#iloc 
#df.iloc[row_index,column_index]
df.iloc[1:10,4:]
# Out:
#           owner  age  power          brand
# 1   First Owner  4.0  350.0  Royal Enfield
# 2   First Owner  8.0  675.0        Triumph
# 3   First Owner  4.0  180.0            TVS
# 4   First Owner  3.0  150.0         Yamaha
# 5   First Owner  6.0  150.0         Yamaha
# 6   First Owner  3.0  160.0          Honda
# 7   First Owner  3.0  100.0           Hero
# 8   First Owner  3.0  350.0  Royal Enfield
# 9  Second Owner  7.0  500.0  Royal Enfield

# %%
# diff btw loc,iloc
#loc=label for column,iloc=index for column
#loc=include given last index,#exclude last given index

# %%
df['price']
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df['price'].min()
# Out:
# np.float64(4400.0)

# %%
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
df['price'].mean()
# Out:
# np.float64(68295.41763660868)

# %%
df['price'].median()
# Out:
# np.float64(43000.0)

# %%
df['price'].std()
# Out:
# np.float64(90718.59520524176)

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.columns=['bike_name', 'bike_price', 'city', 'kms_driven', 'owner', 'bike_age', 'power',
       'brand']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns=['bike_name', 'bike_price', 'city', 'kms_driven', 'owner', 'bike_age', 'power',
#       2        'brand']
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
# price<50k
df['price']<=50000
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645    False
# 32646     True
# 32647     True
# Name: price, Length: 32648, dtype: bool

# %%
under_50k=df[df['price']<=50000]
under_50k.head()
# Out:
#                               bike_name    price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7   Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                  Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                  Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17               Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
#
#           owner  age  power   brand
# 0   First Owner  3.0  110.0     TVS
# 7   First Owner  3.0  100.0    Hero
# 13  First Owner  8.0  100.0   Bajaj
# 14  First Owner  7.0  125.0   Bajaj
# 17  First Owner  5.0  150.0  Suzuki

# %%
under_50k['price'].max()
# Out:
# np.float64(50000.0)

# %%
under_50k.shape
# Out:
# (19114, 8)

# %%
# functions for columns
under_50k['brand'].value_counts()
# Out:
# brand
# Bajaj            7143
# Hero             6258
# Yamaha           2250
# Suzuki           1295
# Honda            1178
# TVS               936
# Mahindra           31
# Royal Enfield      22
# LML                 1
# Name: count, dtype: int64

# %%
under_50k['owner'].value_counts()
# Out:
# owner
# First Owner             17447
# Second Owner             1604
# Third Owner                57
# Fourth Owner Or More        6
# Name: count, dtype: int64

# %%
z=under_50k[under_50k['owner']=='First Owner']
z.head()
# Out:
#                               bike_name    price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 7   Hero Splendor Plus Self Alloy 100cc  45000.0      Delhi     12645.0
# 13                  Bajaj Discover 100M  29499.0      Delhi     20000.0
# 14                  Bajaj Discover 125M  29900.0      Delhi     20000.0
# 17               Suzuki Gixxer SF 150cc  48000.0     Mumbai     24725.0
#
#           owner  age  power   brand
# 0   First Owner  3.0  110.0     TVS
# 7   First Owner  3.0  100.0    Hero
# 13  First Owner  8.0  100.0   Bajaj
# 14  First Owner  7.0  125.0   Bajaj
# 17  First Owner  5.0  150.0  Suzuki

# %%
## mini
z.min()
# Out:
# bike_name     Bajaj  Pulsar 180cc
# price                      4400.0
# city                   24 Pargana
# kms_driven                   22.0
# owner                 First Owner
# age                           2.0
# power                       100.0
# brand                       Bajaj
# dtype: object

# %%
z['price'].min()
# Out:
# np.float64(4400.0)

# %%
z['brand'].value_counts()
# Out:
# brand
# Bajaj            6356
# Hero             5541
# Yamaha           2187
# Suzuki           1286
# Honda            1131
# TVS               905
# Mahindra           27
# Royal Enfield      13
# LML                 1
# Name: count, dtype: int64

# %%
z['brand'].unique()
# Out:
# array(['TVS', 'Hero', 'Bajaj', 'Suzuki', 'Yamaha', 'Honda', 'Mahindra',
#        'Royal Enfield', 'LML'], dtype=object)

# %%
z['brand'].nunique()
# Out:
# 9

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
# filtering data with multiple conditions
df[(df['price']<=100000)&(df['owner']=='First Owner')&(df['age']<=2)]
# Out:
#                                 bike_name    price       city  kms_driven  \
# 22    Hero Splendor iSmart Plus IBS 110cc  46500.0      Delhi      3500.0
# 29                Honda X-Blade 160CC ABS  81200.0     Mettur      9100.0
# 47             Mahindra Centuro NXT 110cc  28000.0     Jaipur     45000.0
# 95                     Bajaj Pulsar 150cc  60000.0       Pune      2000.0
# 96             Suzuki Gixxer Fi 150cc ABS  96700.0   Vadodara      5100.0
# ...                                   ...      ...        ...         ...
# 8335              Bajaj Pulsar 150cc Neon  72000.0       Pune      3162.0
# 8531                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 8536               Hero Glamour i3s 125cc  75000.0    Gurgaon      7488.0
# 8796                 Hero Xtreme 200R ABS  85000.0  Bangalore        40.0
# 9322            TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner  age  power     brand
# ...

# %%
k=df[(df['price']<=100000)&(df['owner']=='First Owner')&(df['age']<=2)&(df['brand']=='Bajaj')]
k
# Out:
#                              bike_name    price        city  kms_driven  \
# 95                  Bajaj Pulsar 150cc  60000.0        Pune      2000.0
# 340        Bajaj Pulsar 125cc Disc CBS  47000.0       Banki     14009.0
# 341           Bajaj Avenger Street 220  95000.0       Delhi     11000.0
# 510                 Bajaj Pulsar 150cc  66000.0       Delhi     15000.0
# 619           Bajaj V15 150cc POWER UP  35000.0      Mumbai     26000.0
# 889   Bajaj Pulsar 150cc Rear Disc ABS  85000.0    Balaghat      2500.0
# 1340         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1401                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1423                Bajaj Pulsar 150cc  67000.0     Chennai      6266.0
# 1445         Bajaj Discover 125cc Disc  39000.0   Faridabad      9923.0
# 1818             Bajaj CT 100 ES Alloy  39000.0   Faridabad      2564.0
# 1819     Bajaj Platina  Alloy ES-100cc  39000.0   Faridabad     12193.0
# ...

# %%
k['brand'].value_counts()
# Out:
# brand
# Bajaj    41
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\Python\Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df[['price','kms_driven','age','power']]
# Out:
#           price  kms_driven   age  power
# 0       35000.0     17654.0   3.0  110.0
# 1      119900.0     11000.0   4.0  350.0
# 2      600000.0       110.0   8.0  675.0
# 3       65000.0     16329.0   4.0  180.0
# 4       80000.0     10000.0   3.0  150.0
# ...         ...         ...   ...    ...
# 32643   39000.0     22000.0   4.0  100.0
# 32644   30000.0      6639.0   9.0  180.0
# 32645   60000.0     20373.0   6.0  220.0
# 32646   15600.0     84186.0  16.0  125.0
# 32647   22000.0     60857.0  13.0  150.0
#
# [32648 rows x 4 columns]

# %%
catgorical=df.select_dtypes(include='O') # capital o means object
catgorical.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
numerical=df.select_dtypes(exclude="O")
numerical.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
combined_df=pd.concat([catgorical,numerical],axis='columns')
combined_df.head()
# Out:
#                               bike_name       city        owner  \
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1           Royal Enfield Classic 350cc      Delhi  First Owner
# 2                  Triumph Daytona 675R      Delhi  First Owner
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
#
#            brand     price  kms_driven  age  power
# 0            TVS   35000.0     17654.0  3.0  110.0
# 1  Royal Enfield  119900.0     11000.0  4.0  350.0
# 2        Triumph  600000.0       110.0  8.0  675.0
# 3            TVS   65000.0     16329.0  4.0  180.0
# 4         Yamaha   80000.0     10000.0  3.0  150.0

# %%
catgorical.shape  # before concatenation shape of both data types should be same
# Out:
# (32648, 4)

# %%
numerical.shape
# Out:
# (32648, 4)

# %%
import numpy as pd

# %%
# to delete columns  but drop do not delete it actually
df.drop(['bike_name'],axis='columns')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.drop(['bike_name'],axis='columns',inplace=True)
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df.drop(['age','power'],axis='columns')  # multiple columns removing
# Out:
#           price       city  kms_driven        owner          brand
# 0       35000.0  Ahmedabad     17654.0  First Owner            TVS
# 1      119900.0      Delhi     11000.0  First Owner  Royal Enfield
# 2      600000.0      Delhi       110.0  First Owner        Triumph
# 3       65000.0  Bangalore     16329.0  First Owner            TVS
# 4       80000.0  Bangalore     10000.0  First Owner         Yamaha
# ...         ...        ...         ...          ...            ...
# 32643   39000.0      Delhi     22000.0  First Owner           Hero
# 32644   30000.0     Karnal      6639.0  First Owner            TVS
# 32645   60000.0      Delhi     20373.0  First Owner          Bajaj
# 32646   15600.0     Jaipur     84186.0  First Owner           Hero
# 32647   22000.0       Pune     60857.0  First Owner          Bajaj
#
# [32648 rows x 5 columns]

# %%
# to add column in data frame
df['dummy']="upflairs"
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand     dummy
# 0                TVS  upflairs
# 1      Royal Enfield  upflairs
# 2            Triumph  upflairs
# 3                TVS  upflairs
# ...

# %%
df["fake_price"]=df["price"]+1000
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand     dummy  fake_price
# 0                TVS  upflairs     36000.0
# 1      Royal Enfield  upflairs    120900.0
# 2            Triumph  upflairs    601000.0
# ...

# %%
df.drop(['dummy','fake_price'],axis='columns',inplace =True)
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df.head()
# Out:
#       price       city  kms_driven        owner  age  power          brand
# 0   35000.0  Ahmedabad     17654.0  First Owner  3.0  110.0            TVS
# 1  119900.0      Delhi     11000.0  First Owner  4.0  350.0  Royal Enfield
# 2  600000.0      Delhi       110.0  First Owner  8.0  675.0        Triumph
# 3   65000.0  Bangalore     16329.0  First Owner  4.0  180.0            TVS
# 4   80000.0  Bangalore     10000.0  First Owner  3.0  150.0         Yamaha

# %%
df[df['brand']=='KTM']
# Out:
#           price        city  kms_driven         owner  age  power brand
# 33     180000.0        Pune     17700.0   First Owner  4.0  390.0   KTM
# 35      70000.0      Nashik    100000.0  Second Owner  8.0  200.0   KTM
# 39     179000.0   Bangalore      3400.0   First Owner  2.0  200.0   KTM
# 65      94700.0    Baripara     32700.0   First Owner  4.0  200.0   KTM
# 83     130000.0  Gandhidham     17500.0  Second Owner  4.0  250.0   KTM
# ...         ...         ...         ...           ...  ...    ...   ...
# 32541  196700.0      Mumbai     13216.0   First Owner  4.0  390.0   KTM
# 32560  196700.0      Mumbai     13216.0   First Owner  4.0  390.0   KTM
# 32579  196700.0      Mumbai     13216.0   First Owner  4.0  390.0   KTM
# 32598  196700.0      Mumbai     13216.0   First Owner  4.0  390.0   KTM
# 32636  196700.0      Mumbai     13216.0   First Owner  4.0  390.0   KTM
#
# [1077 rows x 7 columns]

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (32648, 7)

# %%
df.duplicated().sum()  # number of duplicate data
# Out:
# np.int64(25328)

# %%
df.drop_duplicates()
# Out:
#          price       city  kms_driven        owner  age  power  \
# 0      35000.0  Ahmedabad     17654.0  First Owner  3.0  110.0
# 1     119900.0      Delhi     11000.0  First Owner  4.0  350.0
# 2     600000.0      Delhi       110.0  First Owner  8.0  675.0
# 3      65000.0  Bangalore     16329.0  First Owner  4.0  180.0
# 4      80000.0  Bangalore     10000.0  First Owner  3.0  150.0
# ...        ...        ...         ...          ...  ...    ...
# 9362   25000.0      Delhi     48587.0  First Owner  8.0  150.0
# 9369   35000.0  Bangalore     60000.0  First Owner  9.0  220.0
# 9370  450000.0    Jodhpur      3430.0  First Owner  4.0  750.0
# 9371  139000.0  Hyderabad     21300.0  First Owner  4.0  400.0
# 9372   80000.0  Hyderabad      7127.0  First Owner  5.0  220.0
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...               ...
# 9362             Hero
# ...

# %%
df
# Out:
#           price       city  kms_driven        owner   age  power  \
# 0       35000.0  Ahmedabad     17654.0  First Owner   3.0  110.0
# 1      119900.0      Delhi     11000.0  First Owner   4.0  350.0
# 2      600000.0      Delhi       110.0  First Owner   8.0  675.0
# 3       65000.0  Bangalore     16329.0  First Owner   4.0  180.0
# 4       80000.0  Bangalore     10000.0  First Owner   3.0  150.0
# ...         ...        ...         ...          ...   ...    ...
# 32643   39000.0      Delhi     22000.0  First Owner   4.0  100.0
# 32644   30000.0     Karnal      6639.0  First Owner   9.0  180.0
# 32645   60000.0      Delhi     20373.0  First Owner   6.0  220.0
# 32646   15600.0     Jaipur     84186.0  First Owner  16.0  125.0
# 32647   22000.0       Pune     60857.0  First Owner  13.0  150.0
#
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#          price       city  kms_driven        owner  age  power  \
# 0      35000.0  Ahmedabad     17654.0  First Owner  3.0  110.0
# 1     119900.0      Delhi     11000.0  First Owner  4.0  350.0
# 2     600000.0      Delhi       110.0  First Owner  8.0  675.0
# 3      65000.0  Bangalore     16329.0  First Owner  4.0  180.0
# 4      80000.0  Bangalore     10000.0  First Owner  3.0  150.0
# ...        ...        ...         ...          ...  ...    ...
# 9362   25000.0      Delhi     48587.0  First Owner  8.0  150.0
# 9369   35000.0  Bangalore     60000.0  First Owner  9.0  220.0
# 9370  450000.0    Jodhpur      3430.0  First Owner  4.0  750.0
# 9371  139000.0  Hyderabad     21300.0  First Owner  4.0  400.0
# 9372   80000.0  Hyderabad      7127.0  First Owner  5.0  220.0
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...               ...
# 9362             Hero
# ...

# %%
df.shape
# Out:
# (7320, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]   # filtering duplicate data in df
# Out:
# Empty DataFrame
# Columns: [price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
combined_df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
combined_df[combined_df.duplicated()]
# Out:
#                              bike_name       city        owner          brand  \
# 19                 Bajaj Discover 125M      Delhi  First Owner          Bajaj
# 20              Bajaj Pulsar RS200 ABS  Bangalore  First Owner          Bajaj
# 21              Suzuki Gixxer SF 150cc     Mumbai  First Owner         Suzuki
# 25                  Bajaj Pulsar NS200  Bangalore  First Owner          Bajaj
# 90     Royal Enfield Thunderbird 350cc     Mumbai  First Owner  Royal Enfield
# ...                                ...        ...          ...            ...
# 32643           Hero Passion Pro 100cc      Delhi  First Owner           Hero
# 32644             TVS Apache RTR 180cc     Karnal  First Owner            TVS
# 32645         Bajaj Avenger Street 220      Delhi  First Owner          Bajaj
# 32646        Hero Super Splendor 125cc     Jaipur  First Owner           Hero
# 32647               Bajaj Pulsar 150cc       Pune  First Owner          Bajaj
#
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1344
# Hero               1141
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              52
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
filter_df=df[(df['brand']=='KTM')|(df['brand']=="Suzuki")|(df['brand']=="Jawa")]
filter_df
# Out:
#          price       city  kms_driven         owner  age  power   brand
# 17     48000.0     Mumbai     24725.0   First Owner  5.0  150.0  Suzuki
# 33    180000.0       Pune     17700.0   First Owner  4.0  390.0     KTM
# 35     70000.0     Nashik    100000.0  Second Owner  8.0  200.0     KTM
# 39    179000.0  Bangalore      3400.0   First Owner  2.0  200.0     KTM
# 49     97000.0      Delhi      4400.0   First Owner  3.0  150.0  Suzuki
# ...        ...        ...         ...           ...  ...    ...     ...
# 9195   70000.0      Thane     49347.0   First Owner  9.0  200.0     KTM
# 9255  135000.0  Bangalore      1050.0   First Owner  3.0  125.0     KTM
# 9281   63000.0  Bangalore     19100.0   First Owner  5.0  150.0  Suzuki
# 9282  139100.0      Delhi     25500.0   First Owner  5.0  390.0     KTM
# 9348  195000.0     Mumbai      4568.0   First Owner  4.0  390.0     KTM
#
# [585 rows x 7 columns]

# %%
brand_ls=["KTM","Suzuki","Jawa"]
brand_ls
# Out:
# ['KTM', 'Suzuki', 'Jawa']

# %%
brand_ls=["KTM","Suzuki","Jawa"]
df[df['brand'].isin(brand_ls)]
# Out:
#          price       city  kms_driven         owner  age  power   brand
# 17     48000.0     Mumbai     24725.0   First Owner  5.0  150.0  Suzuki
# 33    180000.0       Pune     17700.0   First Owner  4.0  390.0     KTM
# 35     70000.0     Nashik    100000.0  Second Owner  8.0  200.0     KTM
# 39    179000.0  Bangalore      3400.0   First Owner  2.0  200.0     KTM
# 49     97000.0      Delhi      4400.0   First Owner  3.0  150.0  Suzuki
# ...        ...        ...         ...           ...  ...    ...     ...
# 9195   70000.0      Thane     49347.0   First Owner  9.0  200.0     KTM
# 9255  135000.0  Bangalore      1050.0   First Owner  3.0  125.0     KTM
# 9281   63000.0  Bangalore     19100.0   First Owner  5.0  150.0  Suzuki
# 9282  139100.0      Delhi     25500.0   First Owner  5.0  390.0     KTM
# 9348  195000.0     Mumbai      4568.0   First Owner  4.0  390.0     KTM
#
# [585 rows x 7 columns]

# %%
city_ls=["Mumbai","Pune","Nashik","Jaipur"]
city_ls
# Out:
# ['Mumbai', 'Pune', 'Nashik', 'Jaipur']

# %%
city_ls=["Mumbai","Pune","Nashik","jaipur"]
filter_df[filter_df['city'].isin(city_ls)]
# Out:
#          price    city  kms_driven         owner  age  power   brand
# 17     48000.0  Mumbai     24725.0   First Owner  5.0  150.0  Suzuki
# 33    180000.0    Pune     17700.0   First Owner  4.0  390.0     KTM
# 35     70000.0  Nashik    100000.0  Second Owner  8.0  200.0     KTM
# 199    85000.0  Mumbai     15000.0   First Owner  7.0  200.0     KTM
# 249    87000.0  Mumbai     20000.0   First Owner  6.0  200.0     KTM
# ...        ...     ...         ...           ...  ...    ...     ...
# 8661  135000.0    Pune      8823.0   First Owner  5.0  390.0     KTM
# 8974  165000.0    Pune     26000.0   First Owner  5.0  390.0     KTM
# 8983   58000.0  Mumbai      6000.0   First Owner  5.0  150.0  Suzuki
# 9034   95000.0  Mumbai     20000.0   First Owner  6.0  200.0     KTM
# 9348  195000.0  Mumbai      4568.0   First Owner  4.0  390.0     KTM
#
# [138 rows x 7 columns]

# %%
filter_df['city'].value_counts()
# Out:
# city
# Delhi          106
# Mumbai          96
# Bangalore       70
# Pune            39
# Hyderabad       27
#               ...
# Bhubaneswar      1
# Raigarh(mh)      1
# Adyar            1
# Pondicherry      1
# Berhampore       1
# Name: count, Length: 112, dtype: int64

# %%
filter_df['city'].value_counts()
# Out:
# city
# Delhi          106
# Mumbai          96
# Bangalore       70
# Pune            39
# Hyderabad       27
#               ...
# Bhubaneswar      1
# Raigarh(mh)      1
# Adyar            1
# Pondicherry      1
# Berhampore       1
# Name: count, Length: 112, dtype: int64

# %%
Jaipur=df[df['city']=="Jaipur"]
Jaipur
# Out:
#          price    city  kms_driven         owner   age  power            brand
# 47     28000.0  Jaipur     45000.0   First Owner   2.0  110.0         Mahindra
# 134    47000.0  Jaipur     70000.0   First Owner   6.0  150.0           Suzuki
# 166   123600.0  Jaipur      7702.0   First Owner   3.0  350.0    Royal Enfield
# 189   435000.0  Jaipur      5550.0  Second Owner   7.0  883.0  Harley-Davidson
# 490    55000.0  Jaipur      2000.0   First Owner   9.0  150.0            Honda
# ...        ...     ...         ...           ...   ...    ...              ...
# 9161   41000.0  Jaipur      8000.0   First Owner   6.0  110.0         Mahindra
# 9187  520000.0  Jaipur       399.0   First Owner   2.0  750.0  Harley-Davidson
# 9197   90000.0  Jaipur     17000.0   First Owner   7.0  350.0    Royal Enfield
# 9198   83800.0  Jaipur     21540.0  Second Owner  10.0  350.0    Royal Enfield
# 9259   37000.0  Jaipur      8030.0   First Owner   4.0  110.0           Yamaha
#
# [299 rows x 7 columns]

# %%
Jaipur=df[df['city']=="Jaipur"].value_counts()
Jaipur
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Jaipur=df[df['city']=="Jaipur"].value_counts()
#       2 Jaipur
#
# NameError: name 'df' is not defined

# %%
Jaipur['brand'].value_counts()
# Out:
# brand
# Hero               91
# Bajaj              63
# Honda              39
# TVS                29
# Yamaha             27
# Royal Enfield      23
# KTM                 7
# Mahindra            6
# Harley-Davidson     6
# Suzuki              4
# Benelli             2
# Kawasaki            1
# Hyosung             1
# Name: count, dtype: int64

# %%
brand_ls=["KTM","TVS","Suzuki"]
brand_ls
# Out:
# ['KTM', 'TVS', 'Suzuki']

# %%
Jaipur_bikes=Jaipur[Jaipur['brand'].isin(brand_ls)]
Jaipur_bikes
# Out:
#           price    city  kms_driven         owner   age   power   brand
# 134     47000.0  Jaipur     70000.0   First Owner   6.0   150.0  Suzuki
# 617   1260000.0  Jaipur     17000.0   First Owner   4.0  1300.0  Suzuki
# 888    147000.0  Jaipur     15000.0   First Owner   6.0   390.0     KTM
# 1132    98000.0  Jaipur       749.0   First Owner   1.0   160.0     TVS
# 1304    63000.0  Jaipur      1639.0   First Owner   4.0   160.0     TVS
# 2070   185000.0  Jaipur      2845.0   First Owner   3.0   310.0     TVS
# 2302    19542.0  Jaipur     56592.0   First Owner   9.0   160.0     TVS
# 3364    30000.0  Jaipur     27000.0   First Owner   6.0   110.0     TVS
# 3904    51000.0  Jaipur     18314.0   First Owner   7.0   160.0     TVS
# 3907    47000.0  Jaipur     26000.0   First Owner   8.0   160.0     TVS
# 3920    26500.0  Jaipur      2342.0   First Owner   9.0   110.0     TVS
# 3922    26000.0  Jaipur     24000.0   First Owner   7.0   110.0     TVS
# ...

# %%
Jaipur_bikes.shape
# Out:
# (40, 7)

# %%
bike_70k=Jaipur_bikes[Jaipur_bikes['price']<=70000]
bike_70k
# Out:
#         price    city  kms_driven         owner   age  power   brand
# 134   47000.0  Jaipur     70000.0   First Owner   6.0  150.0  Suzuki
# 1304  63000.0  Jaipur      1639.0   First Owner   4.0  160.0     TVS
# 2302  19542.0  Jaipur     56592.0   First Owner   9.0  160.0     TVS
# 3364  30000.0  Jaipur     27000.0   First Owner   6.0  110.0     TVS
# 3904  51000.0  Jaipur     18314.0   First Owner   7.0  160.0     TVS
# 3907  47000.0  Jaipur     26000.0   First Owner   8.0  160.0     TVS
# 3920  26500.0  Jaipur      2342.0   First Owner   9.0  110.0     TVS
# 3922  26000.0  Jaipur     24000.0   First Owner   7.0  110.0     TVS
# 3936  70000.0  Jaipur     28112.0   First Owner   4.0  150.0  Suzuki
# 4063  33000.0  Jaipur     18677.0   First Owner   6.0  100.0     TVS
# 4371  68000.0  Jaipur     11123.0   First Owner   5.0  160.0     TVS
# 4607  23000.0  Jaipur     28895.0   First Owner   8.0  100.0     TVS
# 4851  45000.0  Jaipur     20431.0   First Owner   7.0  160.0     TVS
# ...

# %%
bike_70k.shape
# Out:
# (28, 7)

# %%
bike_70k[(bike_70k['owner']=='First Owner')&(bike_70k['age']<=2)&(bike_70k['power']<=180)]
# Out:
#         price    city  kms_driven        owner  age  power brand
# 7311  70000.0  Jaipur    207102.0  First Owner  2.0  180.0   TVS

# %%
Jaipur.sort_values(by='price')
# Out:
#           price    city  kms_driven         owner   age   power  \
# 2696    14000.0  Jaipur     70756.0   First Owner  13.0   100.0
# 9029    14000.0  Jaipur     50000.0  Second Owner  19.0   100.0
# 3365    15000.0  Jaipur     52391.0   First Owner  15.0   125.0
# 2983    15000.0  Jaipur     48000.0   First Owner  17.0   100.0
# 4092    15244.0  Jaipur     40320.0   First Owner  15.0   125.0
# ...         ...     ...         ...           ...   ...     ...
# 189    435000.0  Jaipur      5550.0  Second Owner   7.0   883.0
# 2599   445600.0  Jaipur      1500.0   First Owner   5.0   750.0
# 7650   478000.0  Jaipur      1234.0   First Owner   3.0   650.0
# 9187   520000.0  Jaipur       399.0   First Owner   2.0   750.0
# 617   1260000.0  Jaipur     17000.0   First Owner   4.0  1300.0
#
#                 brand
# 2696             Hero
# 9029             Hero
# 3365             Hero
# 2983            Bajaj
# 4092             Hero
# ...               ...
# 189   Harley-Davidson
# ...

# %%
Jaipur.sort_values(by='price',ascending=False)
# Out:
#           price    city  kms_driven         owner   age   power  \
# 617   1260000.0  Jaipur     17000.0   First Owner   4.0  1300.0
# 9187   520000.0  Jaipur       399.0   First Owner   2.0   750.0
# 7650   478000.0  Jaipur      1234.0   First Owner   3.0   650.0
# 2599   445600.0  Jaipur      1500.0   First Owner   5.0   750.0
# 189    435000.0  Jaipur      5550.0  Second Owner   7.0   883.0
# ...         ...     ...         ...           ...   ...     ...
# 4092    15244.0  Jaipur     40320.0   First Owner  15.0   125.0
# 2983    15000.0  Jaipur     48000.0   First Owner  17.0   100.0
# 3365    15000.0  Jaipur     52391.0   First Owner  15.0   125.0
# 9029    14000.0  Jaipur     50000.0  Second Owner  19.0   100.0
# 2696    14000.0  Jaipur     70756.0   First Owner  13.0   100.0
#
#                 brand
# 617            Suzuki
# 9187  Harley-Davidson
# 7650         Kawasaki
# 2599  Harley-Davidson
# 189   Harley-Davidson
# ...               ...
# 4092             Hero
# ...

# %%
city_ls=["Delhi"]
city_ls
# Out:
# ['Delhi']

# %%
Delhi=df[df['city']=="Delhi"]
Delhi
# Out:
#          price   city  kms_driven         owner  age  power          brand
# 1     119900.0  Delhi     11000.0   First Owner  4.0  350.0  Royal Enfield
# 2     600000.0  Delhi       110.0   First Owner  8.0  675.0        Triumph
# 5      53499.0  Delhi     25000.0   First Owner  6.0  150.0         Yamaha
# 6      85000.0  Delhi      8200.0   First Owner  3.0  160.0          Honda
# 7      45000.0  Delhi     12645.0   First Owner  3.0  100.0           Hero
# ...        ...    ...         ...           ...  ...    ...            ...
# 9336  220000.0  Delhi      7130.0   First Owner  5.0  320.0         Yamaha
# 9338  138000.0  Delhi      5000.0   First Owner  5.0  410.0  Royal Enfield
# 9340   34400.0  Delhi     24513.0  Second Owner  8.0  150.0          Honda
# 9344   80000.0  Delhi     56968.0   First Owner  8.0  350.0  Royal Enfield
# 9362   25000.0  Delhi     48587.0   First Owner  8.0  150.0           Hero
#
# [1424 rows x 7 columns]

# %%
top_10price=Delhi.sort_values(by='price',ascending=False).head(10)
top_10price
# Out:
#           price   city  kms_driven         owner  age   power            brand
# 4864  1800000.0  Delhi      2600.0   First Owner  4.0  1000.0              BMW
# 7671  1550000.0  Delhi      9800.0  Second Owner  6.0  1000.0           Yamaha
# 3016  1500000.0  Delhi     18000.0   First Owner  4.0  1000.0              BMW
# 6501  1490000.0  Delhi     12500.0   First Owner  5.0  1200.0           Ducati
# 6070  1350000.0  Delhi      4600.0   First Owner  3.0   850.0              BMW
# 7481  1149000.0  Delhi      9875.0   First Owner  6.0  1300.0           Suzuki
# 7064  1100000.0  Delhi     24000.0   First Owner  4.0   107.0  Harley-Davidson
# 7595  1070500.0  Delhi       289.0   First Owner  3.0   959.0           Ducati
# 3007  1000000.0  Delhi      1500.0   First Owner  4.0  1200.0          Triumph
# 4725   950000.0  Delhi     21000.0   First Owner  8.0  1300.0           Suzuki

# %%
top_10price['brand'].value_counts()
# Out:
# brand
# BMW                3
# Ducati             2
# Suzuki             2
# Yamaha             1
# Harley-Davidson    1
# Triumph            1
# Name: count, dtype: int64

# %%
top_10price.to_csv('delhi_top10.csv',index=False) # to share this data

# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\Python\Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
 #then we have to remove it
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
import numpy as np

# %%
dt={"A":[1,2,4,np.nan,5],
    "B":[7,4,np.nan,9,2],
    "C":[np.nan,8,7,5,6],
    "D":[7,4,1,2,5]}
dt
# Out:
# {'A': [1, 2, 4, nan, 5],
#  'B': [7, 4, nan, 9, 2],
#  'C': [nan, 8, 7, 5, 6],
#  'D': [7, 4, 1, 2, 5]}

# %%
df=pd.DataFrame(dt)
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
# missing values present
df.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# D    0
# dtype: int64

# %%
# handling missing values
#2 ways to handle
#1. remove the records
#2.fill records in missing values

# %%
df.dropna(axis=1)
# Out:
#    D
# 0  7
# 1  4
# 2  1
# 3  2
# 4  5

# %%
df.dropna(axis='columns')  # it removed the columns with missing value,rows=0,columns==1
# Out:
#    D
# 0  7
# 1  4
# 2  1
# 3  2
# 4  5

# %%
# remove the records
# to check no. of rows to be removed
# it is should not be more than 12 % ,5% that is no. of rows
df.dropna()  # delete rows containing missing values
# Out:
#      A    B    C  D
# 1  2.0  4.0  8.0  4
# 4  5.0  2.0  6.0  5

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
# fill the empty records
#nan 96
#bad 35
#good 88
#bad 21
#good 84  # na=good

# we will fill constant value
df.fillna(100)
# Out:
#        A      B      C  D
# 0    1.0    7.0  100.0  7
# 1    2.0    4.0    8.0  4
# 2    4.0  100.0    7.0  1
# 3  100.0    9.0    5.0  2
# 4    5.0    2.0    6.0  5

# %%
# fill column vise
df['A'].fillna(1000)
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3    1000.0
# 4       5.0
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B    C  D
# 0  1.0  7.0  NaN  7
# 1  2.0  4.0  8.0  4
# 2  4.0  NaN  7.0  1
# 3  NaN  9.0  5.0  2
# 4  5.0  2.0  6.0  5

# %%
# filling is difficult then removing
# before filling find out if column is numerical or categorical
#numerical==> mean or median
#categorical==> mode

# %%
#we are trying to fill mean in df['B'] column
df['B'].mean()
# Out:
# np.float64(5.5)

# %%
df['B'].median()
# Out:
# np.float64(5.5)

# %%
df['B'].fillna(df['B'].mean())
# Out:
# 0    7.0
# 1    4.0
# 2    5.5
# 3    9.0
# 4    2.0
# Name: B, dtype: float64

# %%
# where to use mean or median
# if data is in normal distribution we will fill MEAN
# otherwise we will fill median

# %%
df=pd.read_csv(r'D:\Python\Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# group by operation = combine data in a grp and then perform operation
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
group=df.groupby('brand')  # it do not show anything but we can do operations
group

# %%
group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
min_prices=group[['price']].min()

# %%
min_prices.index  # we have only one column other one is index
# Out:
# Index(['BMW', 'Bajaj', 'Benelli', 'Ducati', 'Harley-Davidson', 'Hero', 'Honda',
#        'Hyosung', 'Ideal', 'Indian', 'Jawa', 'KTM', 'Kawasaki', 'LML', 'MV',
#        'Mahindra', 'Rajdoot', 'Royal Enfield', 'Suzuki', 'TVS', 'Triumph',
#        'Yamaha', 'Yezdi'],
#       dtype='object', name='brand')

# %%
min_prices.reset_index()   # find out the minimum price brand

# %%
min_prices.sort_values(by='price')

# %%
group['price'].min()
# Out:
# brand
# BMW                255000.0
# Bajaj                6400.0
# Benelli            110700.0
# Ducati             380000.0
# Harley-Davidson    250000.0
# Hero                 5000.0
# Honda               10000.0
# Hyosung            120000.0
# Ideal              100000.0
# Indian             700000.0
# Jawa               146000.0
# KTM                 55000.0
# Kawasaki           110000.0
# LML                  4400.0
# MV                 950000.0
# Mahindra            17800.0
# Rajdoot             75000.0
# Royal Enfield       33500.0
# Suzuki               8000.0
# TVS                  5800.0
# Triumph            500000.0
# Yamaha               9400.0
# Yezdi               68000.0
# Name: price, dtype: float64

# %%
# want to see multiple functions at a time
group['price'].agg(min_price="min",max_price="max",mean_price="mean")
# Out:
#                  min_price  max_price    mean_price
# brand
# BMW               255000.0  1800000.0  6.735000e+05
# Bajaj               6400.0   195000.0  4.903128e+04
# Benelli           110700.0   785000.0  2.983761e+05
# Ducati            380000.0  1500000.0  9.005750e+05
# Harley-Davidson   250000.0  1100000.0  4.734291e+05
# Hero                5000.0   104000.0  3.068307e+04
# Honda              10000.0   800000.0  5.147068e+04
# Hyosung           120000.0   493500.0  2.432084e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.884286e+05
# KTM                55000.0   860000.0  1.479469e+05
# Kawasaki          110000.0  1100000.0  4.167116e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.266667e+06
# Mahindra           17800.0   175000.0  7.005780e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
df['brand'].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
df['brand'].value_counts().values
# Out:
# array([2081, 1346, 1142,  676,  651,  481,  375,  203,   91,   61,   53,
#          50,   46,   21,   20,   10,    7,    3,    3,    1,    1,    1,
#           1])

# %%
group.get_group("KTM")
# Out:
#              bike_name     price        city  kms_driven         owner  age  \
# 33        KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35      KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39    KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65      KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83      KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                ...       ...         ...         ...           ...  ...
# 9070      KTM RC 200cc  140000.0  Berhampore      2600.0   First Owner  6.0
# 9195    KTM Duke 200cc   70000.0       Thane     49347.0   First Owner  9.0
# 9255    KTM Duke 125cc  135000.0   Bangalore      1050.0   First Owner  3.0
# 9282    KTM Duke 390cc  139100.0       Delhi     25500.0   First Owner  5.0
# 9348    KTM Duke 390cc  195000.0      Mumbai      4568.0   First Owner  4.0
#
#       power brand
# 33    390.0   KTM
# ...

# %%
group.get_group("Honda")
# Out:
#                           bike_name     price       city  kms_driven  \
# 6     Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 27          Honda CBF Stunner 125cc   20800.0  Faridabad     30500.0
# 29          Honda X-Blade 160CC ABS   81200.0     Mettur      9100.0
# 34           Honda CB Unicorn 150cc   40000.0      Noida     30000.0
# 37             Honda CBR 150R 150cc   65000.0  Allahabad     43000.0
# ...                             ...       ...        ...         ...
# 9250                 Honda CBR 250R   80000.0      Delhi      8000.0
# 9258           Honda CB Unicorn 160   65000.0     Mumbai     18000.0
# 9260      Honda CBR 250R Repsol ABS  120000.0      Noida     14000.0
# 9340         Honda CB Trigger 150cc   34400.0      Delhi     24513.0
# 9346           Honda CBR 150R 150cc   61483.0     Kanpur     28032.0
#
#              owner   age  power  brand
# 6      First Owner   3.0  160.0  Honda
# 27    Second Owner   7.0  125.0  Honda
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
group['owner'].agg(min_price="min",max_price="max",mean_price="mean")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
owner_group=group['owner']
owner_group

# %%
owner_group['price'].agg(min_price="min",max_price="max",mean_price="mean")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 owner_group['price'].agg(min_price="min",max_price="max",mean_price="mean")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\base.py:234, in SelectionMixin.__getitem__(self, key)
#     232 def __getitem__(self, key):
#     233     if self._selection is not None:
# --> 234         raise IndexError(f"Column(s) {self._selection} already selected")
#     236     if isinstance(key, (list, tuple, ABCSeries, ABCIndex, np.ndarray)):
#     237         if len(self.obj.columns.intersection(key)) != len(set(key)):
#
# IndexError: Column(s) owner already selected

# %%
Bajaj=df[df['brand']=="Bajaj"]
Bajaj
# Out:
#                      bike_name     price       city  kms_driven        owner  \
# 12          Bajaj Pulsar NS200   78000.0  Bangalore      9900.0  First Owner
# 13         Bajaj Discover 100M   29499.0      Delhi     20000.0  First Owner
# 14         Bajaj Discover 125M   29900.0      Delhi     20000.0  First Owner
# 15      Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0  First Owner
# 16      Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0  First Owner
# ...                        ...       ...        ...         ...          ...
# 9360        Bajaj Pulsar NS200   48000.0  Allahabad     41939.0  First Owner
# 9361       Bajaj Avenger 220cc   50000.0  Bangalore     29134.0  First Owner
# 9369       Bajaj Avenger 220cc   35000.0  Bangalore     60000.0  First Owner
# 9371     Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0  First Owner
# 9372  Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0  First Owner
#
#       age  power  brand
# ...

# %%
Baja=df[df['brand']=="Bajaj"]
Bajaj_group=Bajaj.groupby('owner')
Bajaj_group['price'].agg(min_price="min",max_price="max",mean_price="mean")
# Out:
#                       min_price  max_price    mean_price
# owner
# First Owner              6400.0   195000.0  49915.159664
# Fourth Owner Or More    11000.0    37000.0  24000.000000
# Second Owner             9000.0   140000.0  41056.980769
# Third Owner              7000.0    85000.0  28565.736842

# %%
# map 
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
label={'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner or More':4}
label
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner or More': 4}

# %%
# we are transforming object column in numerical value

# %%
output=df['owner'].map(label)

# %%
output
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 9362    1.0
# 9369    1.0
# 9370    1.0
# 9371    1.0
# 9372    1.0
# Name: owner, Length: 7324, dtype: float64

# %%
df['owner']=output

# %%
df['owner']=df['owner'].map(label)

# %%
df['owner'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...
