# %% [markdown]
# #Insurance premium production

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Ranjit-Singh-786/insorance-Premium-Prediction/master/insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#y variable=charges
#charges take as EMI
#regression problem statement
#3 algorithm used

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['charges'].mean()
# Out:
# np.float64(13270.422265141257)

# %%
charge_male=df[df['sex']=='male']
charge_male
# Out:
#       age   sex     bmi  children smoker     region      charges
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
# [676 rows x 7 columns]

# %%
charge_male['charges'].mean()
# Out:
# np.float64(13956.751177721893)

# %%
charge_female=df[df['sex']=='female']
charge_female
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
charge_female['charges'].mean()
# Out:
# np.float64(12569.578843835347)

# %%
#population data-->entire data
#sample data--> data taken from population

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
girls=df[df['sex']=='female']
girls
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
df2=girls[girls['charges']<=12569]
df2.head()
# Out:
#     age     sex    bmi  children smoker     region     charges
# 5    31  female  25.74         0     no  southeast   3756.6216
# 6    46  female  33.44         1     no  southeast   8240.5896
# 7    37  female  27.74         3     no  northwest   7281.5056
# 13   56  female  39.82         0     no  southeast  11090.7178
# 16   52  female  30.78         1     no  northeast  10797.3362

# %%
df2['smoker'].value_counts()
# Out:
# smoker
# no    441
# Name: count, dtype: int64

# %%
df3=girls[girls['charges']>=12569]
df3.head()
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 9    60  female  25.840         0     no  northwest  28923.13692
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 20   60  female  36.005         0     no  northeast  13228.84695
# 23   34  female  31.920         1    yes  northeast  37701.87680

# %%
df3['smoker'].value_counts()
# Out:
# smoker
# yes    115
# no     106
# Name: count, dtype: int64

# %%
df2['children'].value_counts()
# Out:
# children
# 0    187
# 1    115
# 2     78
# 3     48
# 4      7
# 5      6
# Name: count, dtype: int64

# %%
df2['region'].value_counts()
# Out:
# region
# southwest    120
# northwest    113
# southeast    112
# northeast     96
# Name: count, dtype: int64

# %%
df2
# Out:
#       age     sex    bmi  children smoker     region      charges
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 13     56  female  39.82         0     no  southeast  11090.71780
# 16     52  female  30.78         1     no  northeast  10797.33620
# ...   ...     ...    ...       ...    ...        ...          ...
# 1331   23  female  33.40         0     no  southwest  10795.93733
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
#
# [441 rows x 7 columns]

# %%
ls=df['bmi']
ls
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
label = []
for w in ls:
    if w<18.5:
        label.append('Underweight')
    elif w >18.5 and w<24.9:
        label.append('HealthyWeight')
    elif w>25.0 and w <29.9:
        label.append('Overweight')
    else:
        label.append('obese')

# %%
len(label)
# Out:
# 1338

# %%
df['healthy_category']=label

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#      healthy_category
# 0          Overweight
# 1               obese
# 2               obese
# 3       HealthyWeight
# 4          Overweight
# ...

# %%
df['healthy_category'].value_counts()
# Out:
# healthy_category
# obese            725
# Overweight       372
# HealthyWeight    221
# Underweight       20
# Name: count, dtype: int64

# %%
healthy_group=df.groupby('healthy_category')

# %%
healthy_group[['charges']].min()
# Out:
#                     charges
# healthy_category
# HealthyWeight     1121.8739
# Overweight        1252.4070
# Underweight       1621.3402
# obese             1131.5066

# %%
healthy_analysis=healthy_group['charges'].agg(min_charges='min',max_charges='max',mean_charges='mean')

# %%
healthy_analysis.sort_values('mean_charges')
# Out:
#                   min_charges  max_charges  mean_charges
# healthy_category
# Underweight         1621.3402  32734.18630   8852.200585
# HealthyWeight       1121.8739  35069.37452  10404.900084
# Overweight          1252.4070  38245.59327  11020.183782
# obese               1131.5066  63770.42801  15420.399577

# %%
health_classes=list(healthy_analysis.index)

# %%
average_charges=(healthy_analysis['mean_charges'].values)

# %%
plt.bar(health_classes,average_charges)
plt.show()

# %%
average_charges1=(healthy_analysis['max_charges'].values)

# %%
plt.bar(health_classes,average_charges1)
plt.show()

# %%
average_charges2=(healthy_analysis['min_charges'].values)

# %%
plt.bar(health_classes,average_charges2)
plt.show()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
group_by_region=df.groupby('region')
group_by_region

# %%
group_by_region[['charges']].min()
# Out:
#              charges
# region
# northeast  1694.7964
# northwest  1621.3402
# southeast  1121.8739
# southwest  1241.5650

# %%
group_by_region[['charges']].max()
# Out:
#                charges
# region
# northeast  58571.07448
# northwest  60021.39897
# southeast  63770.42801
# southwest  52590.82939

# %%
group_by_region[['charges']].mean()
# Out:
#                 charges
# region
# northeast  13406.384516
# northwest  12417.575374
# southeast  14735.411438
# southwest  12346.937377

# %%
region_analysis=group_by_region['charges'].agg(min_charges='min',max_charges='max',mean_charges='mean')

# %%
region_analysis.sort_values('mean_charges')
# Out:
#            min_charges  max_charges  mean_charges
# region
# southwest    1241.5650  52590.82939  12346.937377
# northwest    1621.3402  60021.39897  12417.575374
# northeast    1694.7964  58571.07448  13406.384516
# southeast    1121.8739  63770.42801  14735.411438

# %%
region_classes=list(region_analysis.index)

# %%
average_charges=(region_analysis['mean_charges'].values)

# %%
plt.bar(region_classes,average_charges)
plt.show()

# %%
average_charges1=(region_analysis['max_charges'].values)

# %%
plt.bar(region_classes,average_charges1)
plt.show()

# %%
average_charges2=(region_analysis['min_charges'].values)

# %%
plt.bar(region_classes,average_charges2)
plt.show()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#      healthy_category
# 0          Overweight
# 1               obese
# 2               obese
# 3       HealthyWeight
# 4          Overweight
# ...

# %%
male_data=df[df['sex']=='male']
male_data
# Out:
#       age   sex     bmi  children smoker     region      charges  \
# 1      18  male  33.770         1     no  southeast   1725.55230
# 2      28  male  33.000         3     no  southeast   4449.46200
# 3      33  male  22.705         0     no  northwest  21984.47061
# 4      32  male  28.880         0     no  northwest   3866.85520
# 8      37  male  29.830         2     no  northeast   6406.41070
# ...   ...   ...     ...       ...    ...        ...          ...
# 1324   31  male  25.935         1     no  northwest   4239.89265
# 1325   61  male  33.535         0     no  northeast  13143.33665
# 1327   51  male  30.030         1     no  southeast   9377.90470
# 1329   52  male  38.600         2     no  southwest  10325.20600
# 1333   50  male  30.970         3     no  northwest  10600.54830
#
#      healthy_category
# 1               obese
# 2               obese
# 3       HealthyWeight
# 4          Overweight
# 8          Overweight
# ...               ...
# ...

# %%
sns.catplot(x='region',y='bmi',data=df,kind='boxen')
plt.show()

# %%
sns.catplot(x='region',y='bmi',data=df,kind='violin')
plt.show()

# %%
sns.catplot(x='region',y='bmi',data=df,kind='swarm')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x='bmi',y='charges',data=df,hue='sex',col='sex')

# %%
region=list(df['region'].value_counts().keys())
no_ofcounts=list(df['region'].value_counts().values)

# %%
region
# Out:
# ['southeast', 'southwest', 'northwest', 'northeast']

# %%
no_ofcounts
# Out:
# [np.int64(364), np.int64(325), np.int64(325), np.int64(324)]

# %%
plt.pie(no_ofcounts,labels=region,autopct="%1.2f%%")
plt.show()

# %%
healthy_cat=list(df['healthy_category'].value_counts().keys())
no_ofcounts=list(df['healthy_category'].value_counts().values)

# %%
healthy_cat
# Out:
# ['obese', 'Overweight', 'HealthyWeight', 'Underweight']

# %%
no_ofcounts
# Out:
# [np.int64(725), np.int64(372), np.int64(221), np.int64(20)]

# %%
plt.pie(no_ofcounts,labels=healthy_cat,autopct="%1.2f%%")
plt.show()

# %%
age=list(df['age'].value_counts().keys())
no_ofcounts=list(df['age'].value_counts().values)

# %%
plt.pie(no_ofcounts,labels=age,autopct="%1.2f%%")
plt.show()

# %%
bin=[0,18.5,24.9,29.9,45]
plt.hist(age,ec="k",bins=bin)
plt.show()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#      healthy_category
# 0          Overweight
# 1               obese
# 2               obese
# 3       HealthyWeight
# 4          Overweight
# ...

# %%
plt.boxplot(df['bmi'])
plt.show()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#      healthy_category
# 0          Overweight
# 1               obese
# 2               obese
# 3       HealthyWeight
# 4          Overweight
# ...

# %%
bmi=list(df['bmi'].values)
charges=list(df['charges'].values)
plt.scatter(age,bmi,color="r",marker="*") 
plt.xlabel("CHARGES")
plt.xlabel("BMI")
plt.title("CHARGES vs BMI")
plt.show()
