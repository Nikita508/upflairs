# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pb
import numpy as np

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns=['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'member']

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  member
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 1         10.34  1.66    Male     No   Sun  Dinner       3
# 2         21.01  3.50    Male     No   Sun  Dinner       3
# 3         23.68  3.31    Male     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# ..          ...   ...     ...    ...   ...     ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 241       22.67  2.00    Male    Yes   Sat  Dinner       2
# 242       17.82  1.75    Male     No   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [244 rows x 7 columns]

# %%
# function
#relplot,catlot
# these two functions can create any kind of chart

# %%
#sns.lineplot()
#sns.boxplot()
#sns.scatterplot()
#sns.countplot()
#sns.barplot()
#sns.histplot()
sns.scatterplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
#relplot=relational plot  used if columns are numerical
# catplot=catgoricalplot   used if one columnn is numerical and other is numerical

# %%
sns.relplot(x='total_bill',y='tip',data=df)
plt.show()# relatinal plot bydefault give scatter plot

# %%
sns.relplot(x='total_bill',y='tip',data=df,kind='line')

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker',col='gender')
plt.show()  # col separated the male and female visitors

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',style='smoker',col='time')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=df,hue='gender',col='day')
plt.show()

# %%
Female=df[df['gender']=='Female']
Female
# Out:
#      total_bill   tip  gender smoker   day    time  member
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# 11        35.26  5.00  Female     No   Sun  Dinner       4
# 14        14.83  3.02  Female     No   Sun  Dinner       2
# 16        10.33  1.67  Female     No   Sun  Dinner       3
# ..          ...   ...     ...    ...   ...     ...     ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch       2
# 229       22.12  2.88  Female    Yes   Sat  Dinner       2
# 238       35.83  4.67  Female     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [87 rows x 7 columns]

# %%
sns.relplot(x='tip',y='total_bill',data=Female,hue='smoker',col='smoker')

# %%
sns.relplot(x='tip',y='total_bill',data=Female,hue='smoker',col='day') # row can be used on place of col

# %%
sns.relplot(x='tip',y='total_bill',data=Female,hue='smoker',row='day')

# %%
# analysis using single column=univariate analysis
# analysis using two columns=bivariate analysis
# analysis using more then two columns=multivariate analysis

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  member
# 0         16.99  1.01  Female     No   Sun  Dinner       2
# 1         10.34  1.66    Male     No   Sun  Dinner       3
# 2         21.01  3.50    Male     No   Sun  Dinner       3
# 3         23.68  3.31    Male     No   Sun  Dinner       2
# 4         24.59  3.61  Female     No   Sun  Dinner       4
# ..          ...   ...     ...    ...   ...     ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner       3
# 240       27.18  2.00  Female    Yes   Sat  Dinner       2
# 241       22.67  2.00    Male    Yes   Sat  Dinner       2
# 242       17.82  1.75    Male     No   Sat  Dinner       2
# 243       18.78  3.00  Female     No  Thur  Dinner       2
#
# [244 rows x 7 columns]

# %%
df['day']. value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(df['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(x='day',data=df,hue='gender')
plt.show()

# %%
sns.countplot(x='day',data=df,hue='smoker')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df)

# %%
# it is strip

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='swarm')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='boxen')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='point')
plt.show()

# %%
df2=sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.columns=['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
       'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
       'alive', 'alone']

# %%
df2
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(x='survived',y='fare',data=df2)
plt.show()

# %%
sns.relplot(x='pclass',y='fare',data=df2,kind='line')

# %%
sns.relplot(x='pclass',y='fare',data=df2,hue='gender')
plt.show()

# %%
sns.relplot(x='pclass',y='fare',data=df2,hue='gender',style='alone')
plt.show()

# %%
sns.relplot(x='pclass',y='fare',data=df2,hue='gender',style='alone',col='gender')
plt.show()

# %%
male=df2[df2['gender']=='male']
male
# Out:
#      survived  pclass gender   age  sibsp  parch     fare embarked   class  \
# 0           0       3   male  22.0      1      0   7.2500        S   Third
# 4           0       3   male  35.0      0      0   8.0500        S   Third
# 5           0       3   male   NaN      0      0   8.4583        Q   Third
# 6           0       1   male  54.0      0      0  51.8625        S   First
# 7           0       3   male   2.0      3      1  21.0750        S   Third
# ..        ...     ...    ...   ...    ...    ...      ...      ...     ...
# 883         0       2   male  28.0      0      0  10.5000        S  Second
# 884         0       3   male  25.0      0      0   7.0500        S   Third
# 886         0       2   male  27.0      0      0  13.0000        S  Second
# 889         1       1   male  26.0      0      0  30.0000        C   First
# 890         0       3   male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.relplot(x='pclass',y='fare',data=male,hue='alone',col='alone')

# %%
sns.relplot(x='pclass',y='fare',data=male,hue='gender',row='alone')

# %%
df2['age'].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
sns.countplot(df2['age'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='age',data=df2,hue='gender')
plt.show()

# %%
sns.catplot(x='age',y='embarked',data=df2)

# %%
sns.catplot(x='age',y='embarked',data=df2,kind='swarm')
plt.show()

# %%
df2
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x='age',y='embarked',data=df2,kind='violin')
plt.show()

# %%
sns.catplot(x='age',y='embarked',data=df2,kind='boxen')
plt.show()
